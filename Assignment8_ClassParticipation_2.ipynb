# %%
import pandas as pd
import matplotlib.pyplot as plt


location = "C:\\Users\\User\\Documents\\DataForMainlandChina.xlsx"
file1 = pd.read_excel(location)
plt.plot(file1.Confirmed, color = "yellow",linewidth=5, markersize=12 )
plt.xlabel("Jan 2020 Feb 2020                      Mar 2020")
plt.title("CHINA")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


location = "C:\\Users\\User\\Documents\\DataForMainlandChina.xlsx"
file1 = pd.read_excel(location)
plt.plot(file1.Dates,file1.Confirmed, color = "yellow",linewidth=5, markersize=12 )
plt.xlabel("Months")
plt.title("CHINA")
plt.show()

# %%
### Not able to make an exact graph, I might consider learning pandas finally.
